# %%
# 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Final_Project/Train_data/oily_scalp
# hairloss, oily_scalp, folliculitis, erythema, dry_scalp, dandruff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-120afe08a93d> in <module>()
# ----> 1 cd /content/drive/MyDrive/Final_Project/Train_data/oily_scalp
#       2 # hairloss, oily_scalp, folliculitis, erythema, dry_scalp, dandruff
#
# NameError: name 'content' is not defined

# %%
from os import chdir as cd
cd('/content/drive/MyDrive/Final_Project/Train_data/dandruff')
# hairloss, oily_scalp, folliculitis, erythema, dry_scalp, dandruff

# %%
# 모듈 및 라이브러리 호출
import os
import glob

from PIL import Image
import cv2

# %%
def resize_images(img_path, target_size):
    images=glob.glob(img_path + "/*.jpg")  
    
    print(len(images), " images to be resized.")
    
    for img in images: # 복사한 폴더 내 파일들을 리사이즈해서 대체
        old_img=Image.open(img)
        new_img=old_img.resize(target_size,Image.ANTIALIAS)
        new_img.save(img, "JPEG")
    
    print(len(images), " images resized.")

# %%
train_path = glob.glob('./*')
for path in train_path: 
    resize_images(path, (224,224))
    print(path)
# Out:
# 2256  images to be resized.
# 2256  images resized.
# ./dandruff_3
# 534  images to be resized.
# 534  images resized.
# ./dandruff_0
# 9523  images to be resized.
# 9523  images resized.
# ./dandruff_2
# 16560  images to be resized.
# 16560  images resized.
# ./dandruff_1
